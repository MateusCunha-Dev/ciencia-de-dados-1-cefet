# %% [markdown]
# # Atividades da aula 03 - Tipos e qualidade de dados
#
# ## Disciplina: Ciência de Dados I
# ### CEFET-MG - Engenharia de Computação - Campus Timóteo
# ### 7º Período

# %% [markdown]
# **Considere os dados a seguir, de funcionários de uma empresa.**
#
# ## Atividade 01 - Tipos de atributos
#
# * **A.** Em uma célula de texto, classifique as colunas de acordo com os tipos de atributos (Nominal, Ordinal, Intervalar ou de Razão)
# * **B.** Usando o numpy, calcule a média de todas as colunas usando `np.mean(dados, axis=0)` e `np.nanmean(dados, axis=0)`. Responda para cada uma das funções: O que o valor obtido na média de cada coluna significa fisicamente?
#
# ## Atividade 02 - Dados ausentes
#
# A coluna Idade (índice 1) possui um valor `np.nan`. Use funções do numpy para encontrar a média das idades válidas e substitua o np.nan por esse valor. Dica: Use `np.isnan()` para criar uma máscara booleana e identificar onde o valor está ausente.
#
# ## Atividade 03 - Inconsistências e replicação
#
# * **A.** Na coluna Salario (índice 3), há um valor negativo que fere a lógica do negócio. Crie um filtro no numpy para encontrar valores de salário menores que zero e transforme-os em positivos (simulando a correção de um erro de digitação de um sinal de menos).
# * **B.** É possível dizer que existem dados duplicados? Se sim, quais e quais medidas poderiam ser tomadas? Escreva em uma célula de texto.
#
# ## Atividade 04 - Anomalias
#
# Isole na matriz o funcionário que possui um salário desproporcional. Considere como outlier qualquer salário que seja maior que R$ 20.000,00. Extraia e imprima apenas a linha desse funcionário.

# %%
import numpy as np

# Matriz de dados (Data Matrix)
# Colunas:
# 0: ID_Funcionario
# 1: Idade (em anos)
# 2: Codigo_Departamento (0 = RH, 1 = TI, 2 = Vendas)
# 3: Salario (em R$)

dados = np.array([
    [101, 25.0, 1.0,  3000.0],
    [102, 30.0, 0.0,  4500.0],
    [103, np.nan, 1.0, 3200.0],
    [104, 45.0, 2.0, -4000.0],
    [105, 29.0, 0.0,  4100.0],
    [106, 35.0, 1.0,  3600.0],
    [107, 40.0, 2.0, 500000.0],
    [106, 34.0, 1.0,  3600.0],
    [108, 35.0, 1.0,  3600.0],
    [108, 35.0, 1.0,  3600.0]
])
