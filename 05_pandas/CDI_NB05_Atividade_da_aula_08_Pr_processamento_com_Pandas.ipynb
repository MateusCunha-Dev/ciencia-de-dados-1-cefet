# %% [markdown]
# # Atividades da aula 08 - Pré-processamento de dados com Pandas
#
# ## Disciplina: Ciência de Dados I
# ### CEFET-MG - Engenharia de Computação - Campus Timóteo
# ### 7º Período
#
# **OBJETIVO:**
#   - Aplicar técnicas de pré-processamento de dados usando a biblioteca Pandas.
#
# **INSTRUÇÕES:**
#   - Resolva cada exercício nas células marcadas com  # SEU CÓDIGO AQUI
#   - Não altere as células de configuração e verificação
#
# **TÓPICOS ABORDADOS:**
#   1. Carregamento e inspeção dos dados
#   2. Pré-processamento: tratamento de valores ausentes, manipulação de atributos e normalização/padronização

# %%
from google.colab import drive
drive.mount('/content/drive')
PATH = 'SEU PATH DE BASES AQUI'

# %%
import pandas as pd
import numpy as np

df = pd.read_csv(f'{PATH}/nb05_db01_vendas_eletronicos.csv')

# %% [markdown]
# ## 1 Tratamento de dados ausentes
# - A) Conte quantos dados ausentes existem em cada coluna. Utilize os métodos isnull() e sum().
# - B) Os valores ausentes podem ser tratados com:
#    - [ ] Média da coluna
#    - [ ] Mediana da coluna
#    - [ ] Moda da coluna
#    - [ ] Máximo ou mínimo da coluna
#    - [ ] Remoção da coluna
#    - [ ] Remoção da linha
#    - [ ] Foward Fill (ffill)
#   - Aplique as modificações e salve o resultado em `df_clean` (não altere o df original).
# - C) Exiba na tela somente as colunas "produto", "qualidade" e "bateria_horas" do `df_clean`.

# %%
# SEU CÓDIGO AQUI

# %% [markdown]
# ## 2 Análise de atributos
#
# - A) Existem colunas que poderiam ser removidas da base de dados? Verifique, reveja o conteúdo teórico e aplique a remoção utilizando alguma técnica de redução de dimensionalidade.
#
# - B) Pense em uma aplicação para esta base de dados. Qual nova coluna poderia ser extraída, mapeada ou construída a partir dos dados pré-existentes? Reveja o conteúdo teórico e inclua esta nova coluna.

# %%
# SEU CÓDIGO AQUI

# %% [markdown]
# ## 3 Normalização e Padronização
#
# - A) NORMALIZE as colunas "bateria_horas", "tela_polegadas" e "qualidade" para o intervalo [0, 1] usando a fórmula min-max:
#
#   $x_{norm} = \frac{(x - min)}{(max - min)} ⟶$   *(Min-max Scaler)*
#
#   Adicione as colunas normalizadas com sufixo "_norm" ao df_clean.
#
# - B) PADRONIZE a coluna "preco_reais" para que ela tenha média ($\mu$) igual a zero e desvio padrão ($\sigma$) igual a 1, usando a fórmula do z-score:
#
#   $x_{std} = \frac{(x - \mu)}{\sigma} ⟶$ *(Standard Scaler)*
#
#   Adicione a coluna normalizada com sufixo "_z_score" ao df_clean.
#
# - C) Analise os dados, pesquise e responda: Aparentemente, quando a padronização ao invés da normalização é indicada?
#
# - D) Por que a coluna "categoria" não pode ser normalizada/padronizada e a coluna "qualidade" sim?

# %%
# SEU CÓDIGO AQUI

# %% [markdown]
# ## 4 Previsão
# Após o pré-processamento dos dados, qual ou quais produtos teria maior chance de venda no próximo mês? Quais são os melhores produtos para uma oferta na black friday?

# %%
# SUA RESPOSTA AQUI
